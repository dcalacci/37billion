# %% [markdown]
# ## Setup - Installing Python packages and various libraries
#
# During last weekend's [37Billion Datathon](http://www.37billionmilechallenge.org), I learned how to use some basic GIS tools.
#
# We were given a shapefile with a series of 250m x 250m grids that covered Massachusetts.
#
# One of the things I immediately wanted to do with the grid shapefile data was compute the distance from each grid cell to the nearest public transit station.
#
# The dataset we were given included a walksheds file that represented the areas that were walkable around public transit hubs, but I wanted to be able to do a more fine-grained analysis.
#
# I knew I could search for a local public transit station given a latitude & longitude, but first, I needed to get the latitude and longitude from the grid cells.
#
# After some trial and error, I figured out how to convert latitude & longitude to a projection's coordinates. Here are the steps:

# %% [markdown]
# ### Install GDAL
# It took me __several hours__ to figure out how to successfully install and link GDAL. This is what worked for me:
#
# 1. Download & install the __GDAL Framework__ from [here](http://www.kyngchaos.com/software/frameworks)
#
#     It'll install to `/Library/frameworks/GDAL.framework/`.
#
# 2. Add `/Library/frameworks/GDAL.framework/Programs` to your PATH environment variable.
#
# This is important, because other packages will use the gdal-config program to determine where to find the GDAL libraries.
#
# 3. run `pip install fiona shapely pyproj` to install [Fiona](http://toblerity.org/fiona/manual.html), [Shapely](http://toblerity.org/shapely/manual.html) and [PyProj](https://code.google.com/p/pyproj/).
#
# 4. Continue with this notebook!

# %% [markdown]
# ## Setup - data files and imports
#  - Import fiona, pyproj, and shapely.
#  - load the grid shapefile

# %%
import os, fiona, pyproj, shapely
import pandas as pd
import numpy as np
import fiona.crs

# put the relative path to the directory that contains the data here
data_dir = "../data/massvehicledata/"
shapefile = os.path.join(data_dir, 'grid_250m_shell.shp')

# %% [markdown]
# ### Grab the PROJ4 string for our shapefile
# As I understand it, a PROJ4 string is a standard way of clearly defining a projection from a coordinate system. You can read more about Proj4 [here.](https://trac.osgeo.org/proj/wiki/GenParms)
#
# Here, fiona does all the work and pulls it out of the shapefile:

# %%
grid_proj_string = None
with fiona.open(shapefile) as source:
    crs = source.crs
    grid_proj_string = fiona.crs.to_string(crs)

# %%
grid_proj_string
# Out:
# '+datum=NAD83 +lat_0=41 +lat_1=41.7166666667 +lat_2=42.6833333333 +lon_0=-71.5 +no_defs +proj=lcc +units=m +x_0=200000 +y_0=750000'

# %% [markdown]
# ### Create a pyproj object from `grid_proj_string`, and project a latitude and longitude.
#
# Pyproj allows us to do coordinate projections in the exact way that I explained in the beginning of the article - all we have to do is give it the PROJ4 string.
#
# `(42.3428482,-71.0938683)` (Northeastern University) in the coordinates used by the grid shapefile is:

# %%
grid_proj = pyproj.Proj(grid_proj_string)

# %%
grid_proj(42.3428482,-71.0938683)
# Out:
# (39363979.08924379, -1495340.013935822)

# %% [markdown]
# ### Getting bounding lat/lon for the first grid cell in the shapefile
# To make sure this works, let's get the bounding box for the very first grid cell in the shapefile.
#
# The bounding box of this grid in lat/lon is:

# %%
import shapely.geometry
with fiona.open(shapefile) as source:
    
    # get the first shape
    shapefile_record = source.next()
    shape = shapely.geometry.asShape(shapefile_record['geometry'])
    minx, miny, maxx, maxy = shape.bounds
    
    maxx_ll, maxy_ll = grid_proj(maxx, maxy, inverse=True)
    minx_ll, miny_ll = grid_proj(minx, miny, inverse=True)
    
    first_bounding_box_ll = shapely.geometry.box(minx_ll, miny_ll, maxx_ll, maxy_ll)

# %% [markdown]
# Bounding box of the first grid cell, in lat/lon:

# %%
first_bounding_box_ll.bounds
# Out:
# (-70.79455544033586, 42.75570216940319, -70.79147634111301, 42.75793388033074)

# %% [markdown]
# Here's where the minimum lat/lon point of this grid is according to google maps:
#
# ![first grid cell](http://maps.google.com/maps/api/staticmap?size=500x300&sensor=false&zoom=10&markers=42.75570216940319,-70.79455544033586)
#
# Seems sort of reasonable - at the very least, the point is on an edge boundary of Massachusetts. I'm not sure if there's a good, reliable way of testing if that's correct, but I'll take it for face value for now.

# %% [markdown]
# ## Grabbing MassGIS Train Data

# %%
train_data_dir = "../data/mass_shapefiles/trains"
trains_shp = os.path.join(train_data_dir, 'TRAINS_NODE.shp')

# %%
trains_proj_string = None
with fiona.open(trains_shp) as source:
    crs = source.crs
    trains_proj_string = fiona.crs.to_string(crs)

# %% [markdown]
# Are they the same projection?

# %%
trains_proj = pyproj.Proj(trains_proj_string)

# %%
grid_proj(42.3428482,-71.0938683) == trains_proj(42.3428482,-71.0938683)
# Out:
# True

# %% [markdown]
# Yes! Hooray! This makes things easier.
#
# ## Get all stations into a dataframe

# %%
coordinates = []
name = []
commuter = []
amtrak = []

with fiona.open(trains_shp) as source:
    
    # get the first shape
    for n, shapefile_record in enumerate(source):
#        if n % 1000 == 0:
#            print "processed ", n, " records out of ", len(source)
        print shapefile_record
        coordinates.append(shapefile_record['geometry']['coordinates'])
        name.append(shapefile_record['properties']['STATION'])
        commuter.append(shapefile_record['properties']['C_RAILSTAT'])
        amtrak.append(shapefile_record['properties']['AMTRAK'])
# Out:
# {'geometry': {'type': 'Point', 'coordinates': (243618.04690682888, 911165.7499995045)}, 'type': 'Feature', 'id': '0', 'properties': OrderedDict([(u'OBJECTID', 95), (u'STATION', u'RIVER WORKS'), (u'C_RAILSTAT', u'Y'), (u'AMTRAK', None), (u'MAP_STA', u'Y')])}
# {'geometry': {'type': 'Point', 'coordinates': (201970.51560367644, 890060.9999970831)}, 'type': 'Feature', 'id': '1', 'properties': OrderedDict([(u'OBJECTID', 96), (u'STATION', u'ASHLAND'), (u'C_RAILSTAT', u'Y'), (u'AMTRAK', None), (u'MAP_STA', u'Y')])}
# {'geometry': {'type': 'Point', 'coordinates': (198032.7968916446, 890741.562504407)}, 'type': 'Feature', 'id': '2', 'properties': OrderedDict([(u'OBJECTID', 97), (u'STATION', u'SOUTHBOROUGH'), (u'C_RAILSTAT', u'Y'), (u'AMTRAK', None), (u'MAP_STA', u'Y')])}
# {'geometry': {'type': 'Point', 'coordinates': (187740.78130280226, 890988.1249911189)}, 'type': 'Feature', 'id': '3', 'properties': OrderedDict([(u'OBJECTID', 98), (u'STATION', u'WESTBOROUGH'), (u'C_RAILSTAT', u'Y'), (u'AMTRAK', None), (u'MAP_STA', u'Y')])}
# {'geometry': {'type': 'Point', 'coordinates': (184764.43751143664, 888534.6249995828)}, 'type': 'Feature', 'id': '4', 'properties': OrderedDict([(u'OBJECTID', 99), (u'STATION', u'GRAFTON'), (u'C_RAILSTAT', u'Y'), (u'AMTRAK', None), (u'MAP_STA', u'Y')])}
# {'geometry': {'type': 'Point', 'coordinates': (254048.28130224347, 936462.8750010505)}, 'type': 'Feature', 'id': '5', 'properties': OrderedDict([(u'OBJECTID', 100), (u'STATION', u'IPSWICH'), (u'C_RAILSTAT', u'Y'), (u'AMTRAK', None), (u'MAP_STA', u'Y')])}
# {'geometry': {'type': 'Point', 'coordinates': (271639.9999878034, 934324.9374995045)}, 'type': 'Feature', 'id': '6', 'properties': OrderedDict([(u'OBJECTID', 101), (u'STATION', u'ROCKPORT'), (u'C_RAILSTAT', u'Y'), (u'AMTRAK', None), (u'MAP_STA', u'Y')])}
# {'geometry': {'type': 'Point', 'coordinates':
), (u'C_RAILSTAT', None), (u'AMTRAK', None), (u'MAP_STA', u'Y')])}
# {'geometry': {'type': 'Point', 'coordinates': (157994.6562899351, 924887.6875012591)}, 'type': 'Feature', 'id': '350', 'properties': OrderedDict([(u'OBJECTID', 84), (u'STATION', u'CPF346'), (u'C_RAILSTAT', None), (u'AMTRAK', None), (u'MAP_STA', u'Y')])}
# {'geometry': {'type': 'Point', 'coordinates': (176245.18750679493, 925082.5000105128)}, 'type': 'Feature', 'id': '351', 'properties': OrderedDict([(u'OBJECTID', 85), (u'STATION', u'CPF-GL'), (u'C_RAILSTAT', None), (u'AMTRAK', None), (u'MAP_STA', None)])}
# {'geometry': {'type': 'Point', 'coordinates': (204698.71880826354, 927301.1249908917)}, 'type': 'Feature', 'id': '352', 'properties': OrderedDict([(u'OBJECTID', 86), (u'STATION', u'CPF307'), (u'C_RAILSTAT', None), (u'AMTRAK', None), (u'MAP_STA', None)])}
# {'geometry': {'type': 'Point', 'coordinates': (238413.12500961125, 905099.8125113882)}, 'type': 'Feature', 'id': '353', 'properties': OrderedDict([(u'OBJECTID', 87), (u'STATION', u'CHELSEA'), (u'C_RAILSTAT', u'Y'), (u'AMTRAK', None), (u'MAP_STA', u'Y')])}
# {'geometry': {'type': 'Point', 'coordinates': (219992.6406096816, 877238.3124880381)}, 'type': 'Feature', 'id': '354', 'properties': OrderedDict([(u'OBJECTID', 88), (u'STATION', u'WALPOLE'), (u'C_RAILSTAT', u'Y'), (u'AMTRAK', None), (u'MAP_STA', u'Y')])}
# {'geometry': {'type': 'Point', 'coordinates': (248354.93750681728, 820356.2500112839)}, 'type': 'Feature', 'id': '355', 'properties': OrderedDict([(u'OBJECTID', 89), (u'STATION', u'NEW BEDFORD'), (u'C_RAILSTAT', None), (u'AMTRAK', None), (u'MAP_STA', u'Y')])}
# {'geometry': {'type': 'Point', 'coordinates': (235502.99999638647, 847500.8125005811)}, 'type': 'Feature', 'id': '356', 'properties': OrderedDict([(u'OBJECTID', 90), (u'STATION', u'EAST TAUNTON (P)'), (u'C_RAILSTAT', u'P'), (u'AMTRAK', None), (u'MAP_STA', u'Y')])}
# {'geometry': {'type': 'Point', 'coordinates': (247908.59381061792, 821638.6249971949)}, 'type': 'Feature', 'id': '357', 'properties': OrderedDict([(u'OBJECTID', 91), (u'STATION', u'NEW BEDFORD (P)'), (u'C_RAILSTAT', u'P'), (u'AMTRAK', None), (u'MAP_STA', u'Y')])}
# {'geometry': {'type': 'Point', 'coordinates': (252536.95310545713, 941800.1875045598)}, 'type': 'Feature', 'id': '358', 'properties': OrderedDict([(u'OBJECTID', 92), (u'STATION', u'ROWLEY'), (u'C_RAILSTAT', u'Y'), (u'AMTRAK', None), (u'MAP_STA', u'Y')])}
# {'geometry': {'type': 'Point', 'coordinates': (249629.3437923491, 919443.9999926984)}, 'type': 'Feature', 'id': '359', 'properties': OrderedDict([(u'OBJECTID', 93), (u'STATION', u'SALEM'), (u'C_RAILSTAT', u'Y'), (u'AMTRAK', None), (u'MAP_STA', u'Y')])}
# {'geometry': {'type': 'Point', 'coordinates': (247555.03129382432, 913906.6250046864)}, 'type': 'Feature', 'id': '360', 'properties': OrderedDict([(u'OBJECTID', 94), (u'STATION', u'SWAMPSCOTT'), (u'C_RAILSTAT', u'Y'), (u'AMTRAK', None), (u'MAP_STA', u'Y')])}

# %%
df = pd.DataFrame({'coordinates': coordinates,
                   'name': name,
                   'commuter': commuter,
                   'amtrak': amtrak
                   })

# %%
df.head().T
# Out:
#                                       0                               1  \
# amtrak                             None                            None
# commuter                              Y                               Y
# coordinates  (243618.046907, 911165.75)  (201970.515604, 890060.999997)
# name                        RIVER WORKS                         ASHLAND
#
#                                           2                               3  \
# amtrak                                 None                            None
# commuter                                  Y                               Y
# coordinates  (198032.796892, 890741.562504)  (187740.781303, 890988.124991)
# name                           SOUTHBOROUGH                     WESTBOROUGH
#
#                                        4
# amtrak                              None
# commuter                               Y
# coordinates  (184764.437511, 888534.625)
# name                             GRAFTON
#
# [4 rows x 5 columns]

# %% [markdown]
# ### Data cleanup
# #### Change 'None' to False, True otherwise

# %%
df['amtrak'] = df['amtrak'].apply(lambda s: True if s else False)
df['commuter'] = df['commuter'].apply(lambda s: True if s else False)

# %%
df.head().T
# Out:
#                                       0                               1  \
# amtrak                            False                           False
# commuter                           True                            True
# coordinates  (243618.046907, 911165.75)  (201970.515604, 890060.999997)
# name                        RIVER WORKS                         ASHLAND
#
#                                           2                               3  \
# amtrak                                False                           False
# commuter                               True                            True
# coordinates  (198032.796892, 890741.562504)  (187740.781303, 890988.124991)
# name                           SOUTHBOROUGH                     WESTBOROUGH
#
#                                        4
# amtrak                             False
# commuter                            True
# coordinates  (184764.437511, 888534.625)
# name                             GRAFTON
#
# [4 rows x 5 columns]

# %%
df.to_csv('mass_trains.csv')

# %% [markdown]
# ## For each grid cell, compute center point

# %%
def get_nearest_station(coords, df):
    df = df[df['amtrak'] == False]
    df = df[df['commuter'] == True]
    df['dist']= df['coordinates'].apply(lambda pt: shapely.geometry.Point(pt[0], pt[1]).distance(shapely.geometry.Point(coords[0], coords[1])))
    mindist = df['dist'].idxmax()
    return (mindist, df.ix[mindist]['dist'])

# %% [markdown]
# For each grid cell, we want to compute the center point and then subsequently compute the distance between that point and the nearest transit station.

# %%
import shapely.geometry
grid_dists = []

with fiona.open(shapefile) as source:
    for shapefile_record in source:
        print shapefile_record
        shape = shapely.geometry.asShape(shapefile_record['geometry'])
        minx, miny, maxx, maxy = shape.bounds
        center = (maxx - minx, maxy - miny)
        shapefile_record['center'] = center
        nearest = get_nearest_station(center, df)
        shapefile_record['nearest_station'] = nearest[0]
        shapefile_record['nearest_dist'] = nearest[1]
        grid_dists.append(nearest[1])
# Out:
# {'geometry': {'type': 'Polygon', 'coordinates': [[(258000.0, 945250.0), (257750.0, 945250.0), (257750.0, 945499.9998999983), (258000.0, 945499.9998999983), (258000.0, 945250.0)]]}, 'type': 'Feature', 'id': '0', 'properties': OrderedDict([(u'g250m_id', 5732), (u'municipal', None), (u'muni_id', 0)])}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-cec8df2fae8a> in <module>()
#       9         center = (maxx - minx, maxy - miny)
#      10         shapefile_record['center'] = center
# ---> 11         nearest = get_nearest_station(center, df)
#      12         shapefile_record['nearest_station'] = nearest[0]
#      13         shapefile_record['nearest_dist'] = nearest[1]
#
# NameError: name 'get_nearest_station' is not defined

# %%
import shapely.geometry
grid_dists = []

with fiona.open(shapefile, 'r') as grids:
    new_driver = grids.driver
    new_crs = grids.crs    
    
    schema = grids.schema.copy()
    schema['properties']['nearest_station'] = 'int'
    schema['properties']['nearest_dist'] = 'float'
#    schema['properties']['normalized_nearest_dist'] = 'float'

    with fiona.collection('join_data_grids.shp', 'w', 'ESRI Shapefile', schema) as output:
        for shapefile_record in grids:
            shape = shapely.geometry.asShape(shapefile_record['geometry'])
            minx, miny, maxx, maxy = shape.bounds
            center = (maxx - minx, maxy - miny)
#            shapefile_record['properties']['center'] = center
            nearest = get_nearest_station(center, df)
            shapefile_record['properties']['nearest_station'] = nearest[0]
            shapefile_record['properties']['nearest_dist'] = nearest[1]
            output.write(shapefile_record)
            grid_dists.append(nearest[1])

# %%
properties['uh'] = 5

# %%
grid_dists = []
distance = Point(x1,y1).distance(Point(x2,y2)
